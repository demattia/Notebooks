# %% [markdown]
# # Gadfly

# %% [markdown]
# Gadfly is a plotting library for Julia. In the notebook it draws by default using the d3 backend so the plots are interactive.

# %%
joinpath(Pkg.dir("Gadfly"), "src", "gadfly.js")
# Out:
# "/Users/demattia/.julia/Gadfly/src/gadfly.js"

# %%
using RDatasets
iris = data("datasets", "iris")
neuro = data("boot", "neuro")
# Out:
# 469x7 DataFrame:
#                   V1     V2     V3    V4    V5    V6
# [1,]        1     NA -203.7  -84.1  18.5    NA    NA
# [2,]        2     NA -203.0  -97.8  25.8 134.7    NA
# [3,]        3     NA -249.0  -92.1  27.8 177.1    NA
# [4,]        4     NA -231.5  -97.5  27.0 150.3    NA
# [5,]        5     NA     NA -130.1  25.8 160.0    NA
# [6,]        6     NA -223.1  -70.7  62.1 197.5    NA
# [7,]        7     NA -164.8  -12.2  76.8 202.8    NA
# [8,]        8     NA -221.6  -81.9  27.5 144.5    NA
# [9,]        9     NA -153.7  -17.0  76.1 222.4    NA
# [10,]      10     NA -184.7  -47.3  74.4 208.9    NA
# [11,]      11     NA     NA -148.8  11.4 137.7    NA
# [12,]      12     NA -197.6   -6.4 137.1    NA    NA
# [13,]      13     NA -247.8  -35.4  80.9 229.5    NA
# [14,]      14     NA -227.0 -104.7  20.2 140.2    NA
# [15,]      15 -233.6 -115.9  -10.5  70.0 202.6    NA
# [16,]      16     NA -232.4 -100.6  16.8 145.1    NA
# ...

# %%
using Gadfly
# Out:
# ...
#     |(
# SynchronousStepCollection,Any) at /Users/demattia/.julia/BinDeps/src/BinDeps.jl:283
# is ambiguous with:
#     |(Any,NAtype) at /Users/demattia/.julia/DataArrays/src/operators.jl:502.
# To fix, define
#     |(SynchronousStepCollection,NAtype)
# before the new definition.
# ...
#     |(Any,SynchronousStepCollection) at /Users/demattia/.julia/BinDeps/src/BinDeps.jl:286
# is ambiguous with:
#     |(NAtype,Any) at /Users/demattia/.julia/DataArrays/src/operators.jl:502.
# To fix, define
#     |(NAtype,SynchronousStepCollection)
# before the new definition.
# ...

# %%
set_default_plot_size(9inch, 9inch/golden);

# %%
plot(data("datasets", "iris"),x="Sepal.Length", y="Sepal.Width", Geom.point)
# Out:
# D3(228.6,141.28256982822595,IOBuffer([0x66,0x75,0x6e,0x63,0x74,0x69,0x6f,0x6e,0x20,0x64  …  0x74,0x5f,0x69,0x64,0x29,0x3b,0x0a,0x7d,0x3b,0x0a],true,true,true,false,23425,9223372036854775807,23426),0,[],[],1,3,[0x9b5bb8606f720402=>([51.94406134541242,73.77850848281355,65.04472962785309,69.41161905533332,47.57717191793219,34.476503635491525,56.310950772892646,56.310950772892646,78.14539791029377,69.41161905533332  …  69.41161905533332,69.41161905533332,86.87917676525421,65.04472962785309,60.67784020037288,73.77850848281355,95.61295562021466,73.77850848281355,56.310950772892646,73.77850848281355],1),0x93b174b2601de7ee=>([81.9292358490566,72.54706603773586,63.1648962264151,58.4738113207547,77.23815094339622,96.00249056603775,58.4738113207547,77.23815094339622,49.091641509433984,72.54706603773586  …  156.98659433962266,166.3687641509434,114.76683018867922,161.677679245283,156.98659433962266,156.98659433962266,138.2222547169811,147.60442452830188,133.53116981132075,119.45791509433963],0)],
# D3(228.6,141.28256982822595,IOBuffer([0x66,0x75,0x6e,0x63,0x74,0x69,0x6f,0x6e,0x20,0x64  …  0x74,0x5f,0x69,0x64,0x29,0x3b,0x0a,0x7d,0x3b,0x0a],true,true,true,false,26466,9223372036854775807,26467),0,[],[],0,3,Dict{Uint64,(Any,Int64)}(),true,false,nothing,true)
# Plot(...)

# %%
# E.g.
@plot(cos(x)/x, 5, 25)
# Out:
# D3(228.6,141.28256982822595,IOBuffer([0x66,0x75,0x6e,0x63,0x74,0x69,0x6f,0x6e,0x20,0x64  …  0x74,0x5f,0x69,0x64,0x29,0x3b,0x0a,0x7d,0x3b,0x0a],true,true,true,false,20677,9223372036854775807,20678),0,[],[],0,3,Dict{Uint64,(Any,Int64)}(),true,false,nothing,true)
# Plot(...)

# %%
some_plot = plot(x=[1,2,3], y=[4,5,6])
draw(PNG("myplot.png", 6inch, 3inch), some_plot)

# %%
draw(D3("mammals.js", 6inch, 6inch), p)
# Out:
# p not defined
# at In[29]:1

# %%
plot(data("datasets", "iris"), x="Sepal.Width", y="Sepal.Length", color="Species")
# Out:
# D3(228.6,141.28256982822595,IOBuffer([0x66,0x75,0x6e,0x63,0x74,0x69,0x6f,0x6e,0x20,0x64  …  0x74,0x5f,0x69,0x64,0x29,0x3b,0x0a,0x7d,0x3b,0x0a],true,true,true,false,33137,9223372036854775807,33138),0,[],[],1,3,[0x3d025c3ca0fc2c5c=>({LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0)  …  LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0)},3),0x5f1ba0c7e62d499a=>([LCHab(70.0,60.0,240.0),LCHab(70.0,60.0,240.0),LCHab(70.0,60.0,240.0),LCHab(70.0,60.0,240.0),LCHab(70.0,60.0,240.0),LCHab(70.0,60.0,240.0),LCHab(70.0,60.0,240.0),LCHab(70.0,60.0,240.0),LCHab(70.0,60.0,240.0),LCHab(70.0,60.0,240.0)  …  LCHab(65.0,70.0,0.0),LCHab(65.0,70.0,0.0),LCHab(65.0,70.0,0.0)
# ...

# %%
srand(37)
plot(x=[1:5000], y=cumsum(randn(500)), Geom.line, Guide.XLabel("time"), Guide.YLabel("random walk"))
# Out:
# D3(228.6,141.28256982822595,IOBuffer([0x66,0x75,0x6e,0x63,0x74,0x69,0x6f,0x6e,0x20,0x64  …  0x74,0x5f,0x69,0x64,0x29,0x3b,0x0a,0x7d,0x3b,0x0a],true,true,true,false,27648,9223372036854775807,27649),0,[],[],0,3,Dict{Uint64,(Any,Int64)}(),true,false,nothing,true)
# Plot(...)
