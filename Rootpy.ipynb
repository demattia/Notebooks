# %%
from rootpy import ROOT
from rootpy.plotting import Hist2D
from rootpy.plotting import Hist
import rootpy.plotting.root2matplotlib as rplt
from rootpy.tree import Tree, TreeModel
from rootpy.io import root_open

# %%
f = root_open("")

# %%
inputFileData = root_open("/home/demattia/cmslpc/uscms_data/d3/demattia/DisplacedLeptons/RefittedStandAloneMuons/Analysis/CMSSW_5_3_8/src/Systematics/Cosmics/Analysis/TrackingEfficiencyFromCosmics/test/Macros/TreeAnalyzers/eff_data_dz10.root")

# %% [markdown]
# This behavior is not really what I wanted. I would like to see two different canvases. I would like to have an option to draw in the same canvas.

# %%
a = rplt.hist(inputFileData.TotalPhi)
b = rplt.hist(inputFileData.TotalEta)
