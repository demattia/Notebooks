# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pylab import *

pylab.rcParams['figure.figsize'] = (10.0, 8.0)

#val = [10**(-6),
val = [2.6033*10**(-8), #1.2380*10**(-8),
       5.116*10**(-8), #1.040*10**(-12),
       2.631*10**(-10), 1.479*10**(-10)]#, 10**(-8), 10**(-10), 10**(-10)]
for i in range(len(val)):
    val[i] = 1000000000*val[i]
names = (#'$\mu^{\pm}$',
         '$\pi^{\pm}$',
         '$K_L$',
         '$\Lambda_0$',
         '$\Sigma^-$'
         # '$D^{\pm}$'
         )
additional_names = (
         '$K_S/K_L$',
         '$K^{\pm}$, 493.667, 8.954*10**(-11)',
         '$\Sigma^+$')
# pos = [105.7]
pos = [139.57018, #497.614,
       497.614, 1115.683,
       # 1189.37
      1197.449]

yticks(fontsize=15)

figure(1)
barh(pos, val, align='center')
xlabel('Lifetime (ns)', fontsize=15)
xticks(fontsize=15)
title('')
xscale('log')
yscale('log')
yticks(pos, names)
grid(True)

show()

# %%
from pylab import *

pylab.rcParams['figure.figsize'] = (10.0, 8.0)

val = [2.6033*10**(-8), 1.2380*10**(-8), 5.116*10**(-8), 8.954*10**(-11), 2.631*10**(-10),
       8.018*10**(-11), 1.479*10**(-10), 1.040*10**(-12), 4.101*10**(-13), 5.00*10**(-13),
       1.638*10**(-12), 1.530*10**(-12), 1.470*10**(-12), 0.46*10**(-12), 1.409*10**(-12),
       5.63*10**(-24), 3*10**(-25)]
for i in range(len(val)):
    val[i] = 1000000000000*val[i]
    # val[i] = 29979245800*val[i]

colors = ['b','b','b','b','b','b','b','b','b','b','b','g','g','b','b','y','c']
names = (#'$\mu^{\pm}$',
         '$\pi^{\pm}$',
         '$K^{\pm}$',
         '$K_L$',
         '$K_S$',
         '$\Lambda_0$',
         '$\Sigma^+$',
         '$\Sigma^-$',
         '$D^{\pm}$',
         '$D_0$',
         '$D_S^{\pm}$',
         '$B^{\pm}$',
         '$B_0$',
         '$B_S$',
         '$B_C^{\pm}$',
         '$\Lambda_b$',
         '$\Delta^{\pm}$',
         '$W^{\pm}$, $Z$'
         )
additional_names = (
         '$K_S/K_L$',
         '$K^{\pm}$, 493.667, 8.954*10**(-11)',
         '$\Sigma^+$')
pos = arange(len(val))+.5

yticks(fontsize=15)

figure(1)
barh(pos, val, align='center', color=colors)
yticks(pos, names)
xlabel('Lifetime [ps]', fontsize=15)
xticks(fontsize=15)
xscale('log')
title('')
grid(True)

show()

# %%
from pylab import *

pylab.rcParams['figure.figsize'] = (10.0, 12.0)

val = [2.6033*10**(-8), 1.2380*10**(-8), 5.116*10**(-8), 8.954*10**(-11), 2.631*10**(-10),
       8.018*10**(-11), 1.479*10**(-10), 1.040*10**(-12), 4.101*10**(-13), 5.00*10**(-13),
       1.638*10**(-12), 1.530*10**(-12), 1.470*10**(-12), 0.46*10**(-12), 1.409*10**(-12),
       5.63*10**(-24), 3*10**(-25), 1.56*10**(-22)]
for i in range(len(val)):
    val[i] = 1000000000000*val[i]
    # val[i] = 29979245800*val[i]

colors = ['b','b','b','b','b','b','b','b','b','b','b','g','g','b','b','y','c','c']
names = (#'$\mu^{\pm}$',
         '$\pi^{\pm}$',
         '$K^{\pm}$',
         '$K_L$',
         '$K_S$',
         '$\Lambda_0$',
         '$\Sigma^+$',
         '$\Sigma^-$',
         '$D^{\pm}$',
         '$D_0$',
         '$D_S^{\pm}$',
         '$B^{\pm}$',
         '$B_0$',
         '$B_S$',
         '$B_C^{\pm}$',
         '$\Lambda_b$',
         '$\Delta^{\pm}$',
         '$W^{\pm}$, $Z$',
         '$H$'
         )
additional_names = (
         '$K_S/K_L$',
         '$K^{\pm}$, 493.667, 8.954*10**(-11)',
         '$\Sigma^+$')
pos = arange(len(val))+.5
# pos = arange(len(val))+.9
# print pos

yticks(fontsize=15)

figure(1)
barh(pos, val, align='center', color=colors, alpha=0.8)
yticks(pos, names)
xlabel('Lifetime [ps]', fontsize=15)
xticks(fontsize=15)
xscale('log')
title('')
grid(True)

show()

# %%
import numpy as np
import matplotlib.pyplot as plt

ax = plt.subplot(111)

tau = 0.05
t = np.arange(0.0, 5.0, 0.01)
s = np.exp(-t/tau)
line, = plt.plot(t, s, lw=2)

plt.ylim(0,1)
plt.show()
