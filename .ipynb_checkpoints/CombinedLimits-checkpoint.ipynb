# %% [markdown]
# # Combined Limits

# %%
import ROOT
from ROOT import TFile, TLine
import rootnotes
import rootprint

# %%
input_dir = "/Users/demattia/Documents/NewPapers/myDir/notes/EXO-14-012/trunk/Figs/CombinedLimits/"
input_dir_acc = "/Users/demattia/Documents/NewPapers/myDir/notes/EXO-14-012/trunk/Figs/CombinedLimits/WithinAcceptance/"

# %%
def draw_line(input_file_name, x_min, y_min, x_max, y_max, text_index = 4, text_size = 0.04):
    input_file = TFile(input_file_name, "R")
    c = input_file.FindObjectAny("c")
    text = c.GetListOfPrimitives()[text_index]
    text.SetText(text.GetX(), text.GetY(), "CMS Preliminary")
    text.SetTextSize(text_size)
    line = TLine(x_min, y_min, x_max, y_max)
    line.Draw()
    line.SetLineColor(8)
    line.SetLineWidth(3)
    name = input_file_name
    if name.endswith(".root"):
        name = name[:-5]
    c.SaveAs(name+"_expectedLimitLine.root")
    c.SaveAs(name+"_expectedLimitLine.pdf")
    c.SaveAs(name+"_expectedLimitLine.png")
    return c, line

# %%
def shift_legend(name, c, ls_y1, ls_y2):
    legend = c.GetListOfPrimitives()[9]
    legend.SetY1(legend.GetY1()+ls_y1)
    legend.SetY2(legend.GetY2()+ls_y2)
    if name.endswith(".root"):
        name = name[:-5]
    c.SaveAs(name+"_expectedLimitLine.root")
    c.SaveAs(name+"_expectedLimitLine.pdf")
    c.SaveAs(name+"_expectedLimitLine.png")
    return c

# %%
cc_1000 = draw_line(input_dir+"/limitsLifetimeMuonsMH1000.root", 0.00362,3.7,0.01948,3.7)
cc_1000[0]
# Out:
# <ROOT.TCanvas object ("c") at 0x7fdc46508860>

# %%
cc_125 = draw_line(input_dir+"/limitsLifetimeMuonsMH125.root", 0.001885,10,0.0113,10)
cc_125[0]
# Out:
# <ROOT.TCanvas object ("c") at 0x7fdc46703430>

# %%
cc_400 = draw_line(input_dir+"/limitsLifetimeMuonsMH400.root", 0.00542,1.65,0.029,1.65)
cc_400[0]
# Out:
# <ROOT.TCanvas object ("c") at 0x7fdc466e4510>

# %%
cc_200 = draw_line(input_dir+"/limitsLifetimeMuonsMH200.root", 0.001885,4.2,0.01143,4.2)
cc_200[0]
# Out:
# <ROOT.TCanvas object ("c") at 0x7fdc46701cf0>

# %%
ls_y1 = -0.24
ls_y2 = -0.24
name = input_dir+"/limitsLifetimeMuons_neutralino.root"
# Use this when not shifting the legend
# cc_neutralino = draw_line(name, 0.0466,0.078,0.175,0.078, 3)
cc_neutralino = draw_line(name, 0.0466,0.044,0.175,0.044, 3)
# cc_neutralino[0]
cc_neutralino_shifted_legend = shift_legend(name, cc_neutralino[0], ls_y1, ls_y2)
cc_neutralino_shifted_legend
# Out:
# <ROOT.TCanvas object ("c") at 0x7fdc463e4710>

# %% [markdown]
# ## Acceptance

# %%
cc_1000 = draw_line(input_dir_acc+"/limitsLifetimeMuonsMH1000.root", 0.00362,3.11,0.01948,3.11)
cc_1000[0]
# Out:
# <ROOT.TCanvas object ("c") at 0x7fdc463d3450>

# %%
cc_125 = draw_line(input_dir_acc+"/limitsLifetimeMuonsMH125.root", 0.001885,0.032,0.01143,0.032)
cc_125[0]
# Out:
# <ROOT.TCanvas object ("c") at 0x7fdc467081a0>

# %%
cc_400 = draw_line(input_dir_acc+"/limitsLifetimeMuonsMH400.root", 0.00542,0.8,0.029,0.8)
cc_400[0]
# Out:
# <ROOT.TCanvas object ("c") at 0x7fdc463d8360>

# %%
cc_200 = draw_line(input_dir_acc+"/limitsLifetimeMuonsMH200.root", 0.001885,0.163,0.01143,0.163)
cc_200[0]
# Out:
# <ROOT.TCanvas object ("c") at 0x7fdc46814790>

# %%
ls_y1 = -0.2
ls_y2 = -0.2
name_acc = input_dir_acc+"/limitsLifetimeMuons_neutralino.root"
# cc_neutralino = draw_line(name_acc, 0.0466,0.00225,0.175,0.00225, 3)
cc_neutralino = draw_line(name_acc, 0.0466,0.00142,0.175,0.00142, 3)
cc_neutralino[0]
cc_neutralino_shifted_legend = shift_legend(name_acc, cc_neutralino[0], ls_y1, ls_y2)
cc_neutralino_shifted_legend
# Out:
# <ROOT.TCanvas object ("c") at 0x7fdc46848c00>
