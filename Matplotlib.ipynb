# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
# plt.plot([8,2,12,4])
# plt.ylabel('some numbers')
# plt.show()
x = np.arange(0, 14, 0.1);
y = 12 - x
plt.plot(x, y, lw = 3)

axvline(x=8, lw=3)

y1 = 0.5 * (40 - 3*x)
y2 = 0.5 * (35 - 3*x)
y3 = 0.5 * (32 - 3*x)
y4 = 0.5 * (28 - 3*x)
plt.plot(x, y1, "g", lw = 2)
plt.plot(x, y2, "g", lw = 2)
plt.plot(x, y3, "g", lw = 2)
plt.plot(x, y4, "g", lw = 2)

plt.plot(8,4, marker="o", color='r', markersize=20)
plt.fill_between(x, y, where=x<=8.0, color="m", hatch="//", alpha=0.5)
plt.ylim(0,20)
plt.ylabel("y")
plt.xlabel("x")
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5,10.5)
