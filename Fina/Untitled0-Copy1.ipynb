# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['close']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
from pandas.io.data import DataReader
from pandas.stats import moments
from datetime import datetime
import matplotlib.pyplot as plt

# %%
ntdof = DataReader("NTDOF",  "yahoo", datetime(2010,1,1), datetime.today())
atvi = DataReader("ATVI",  "yahoo", datetime(2010,1,1), datetime.today())
ea = DataReader("EA",  "yahoo", datetime(2010,1,1), datetime.today())
ttwo = DataReader("TTWO", "yahoo", datetime(2010,1,1), datetime.today())
knm = DataReader("KNM", "yahoo", datetime(2010,1,1), datetime.today())

# %%
atvi.hist()
# Out:
# array([[Axes(0.125,0.563043;0.215278x0.336957),
#         Axes(0.404861,0.563043;0.215278x0.336957),
#         Axes(0.684722,0.563043;0.215278x0.336957)],
#        [Axes(0.125,0.125;0.215278x0.336957),
#         Axes(0.404861,0.125;0.215278x0.336957),
#         Axes(0.684722,0.125;0.215278x0.336957)]], dtype=object)

# %%
plt.figure()
#ntdof["Adj Close"].plot(label='ntdof')
atvi["Adj Close"].plot(label='atvi')
ea["Adj Close"].plot(label='ea')
ttwo["Adj Close"].plot(label='ttwo')
knm["Adj Close"].plot(label='knm')
plt.legend()

# %%
from pandas.tools.plotting import autocorrelation_plot

plt.figure()

autocorrelation_plot(atvi["Adj Close"])

# %%
from pandas.tools.plotting import bootstrap_plot

# %%
bootstrap_plot(atvi["Adj Close"], size=500, samples=500, color='grey')

# %%
plt.figure()
plt.subplot(2,3,1)
plt.plot(atvi["Adj Close"], ea["Adj Close"], 'x')
plt.subplot(2,3,2)
plt.plot(atvi["Adj Close"], ttwo["Adj Close"], 'x')
plt.subplot(2,3,3)
plt.plot(atvi["Adj Close"], knm["Adj Close"], 'x')
plt.subplot(2,3,4)
plt.plot(ea["Adj Close"], ttwo["Adj Close"], 'x')
plt.subplot(2,3,5)
plt.plot(ea["Adj Close"], knm["Adj Close"], 'x')
plt.subplot(2,3,6)
plt.plot(ttwo["Adj Close"], knm["Adj Close"], 'x')

# %%
firstTime = atvi.index[0]
atviFirst = atvi["Adj Close"][0]
atviDiff = 0
eaFirst = ea["Adj Close"][0]
eaDiff = 0
for t,p in zip(atvi.index, atvi["Adj Close"]):
    timeDelta = t - firstTime
    if timeDelta.days >= 7:
        if p - atviFirst > 0 and atviDiff > 0:
            print "trending up"
            print timeDelta, p
        atviDiff = p - atviFirst
        atviFirst = p
        firstTime = t
        # print timeDelta, p
# Out:
# trending up
# 7 days, 0:00:00 10.65
# trending up
# 7 days, 0:00:00 11.16
# trending up
# 7 days, 0:00:00 11.47
# trending up
# 7 days, 0:00:00 11.53
# trending up
# 7 days, 0:00:00 11.57
# trending up
# 7 days, 0:00:00 11.76
# trending up
# 7 days, 0:00:00 10.98
# trending up
# 7 days, 0:00:00 11.44
# trending up
# 7 days, 0:00:00 10.88
# trending up
# 7 days, 0:00:00 10.88
# trending up
# 7 days, 0:00:00 11.0
# trending up
# 7 days, 0:00:00 11.28
# trending up
# 7 days, 0:00:00 11.25
# trending up
# 7 days, 0:00:00 11.51
# trending up
# 7 days, 0:00:00 11.95
# trending up
# 7 days, 0:00:00 12.01
# trending up
# 7 days, 0:00:00 11.39
# trending up
# 7 days, 0:00:00 10.67
# trending up
# 7 days, 0:00:00 10.72
# trending up
# 7 days, 0:00:00 10.92
# trending up
# 7 days, 0:00:00 11.1
# trending up
# 7 days, 0:00:00 11.15
# trending up
# 7 days, 0:00:00 11.3
# trending up
# 7 days, 0:00:00 11.48
# trending up
# 7 days, 0:00:00 11.51
# trending up
# 7 days, 0:00:00 11.57
# trending up
# 7 days, 0:00:00 11.81
# trending up
# 7 days, 0:00:00 11.5
# trending up
# 7 days, 0:00:00 11.75
# trending up
# 7 days, 0:00:00 11.85
# trending up
# 7 days, 0:00:00 12.66
# trending up
# 7 days, 0:00:00 13.16
# trending up
# 7 days, 0:00:00 12.05
# trending up
# 7 days, 0:00:00 11.87
# trending up
# 7 days, 0:00:00 12.11
# trending up
# 7 days, 0:00:00 12.01
# trending up
# 7 days, 0:00:00 12.1
# trending up
# 7 days, 0:00:00 12.14
# trending up
# 7 days, 0:00:00 12.36
# trending up
# 7 days, 0:00:00 12.69
# trending up
# 7 days, 0:00:00 12.65
# trending up
# 7 days, 0:00:00 11.75
# trending up
# 7 days, 0:00:00 11.39
# trending up
# 7 days, 0:00:00 13.55
# trending up
# 7 days, 0:00:00 14.06
# trending up
# 7 days, 0:00:00 14.08
# trending up
# 7 days, 0:00:00 14.46
# trending up
# 7 days, 0:00:00 14.79
# trending up
# 7 days, 0:00:00 14.53
# trending up
# 7 days, 0:00:00 14.88
# trending up
# 7 days, 0:00:00 14.74
# trending up
# 7 days, 0:00:00 15.26
# trending up
# 7 days, 0:00:00 14.9
# trending up
# 7 days, 0:00:00 15.27
# trending up
# 7 days, 0:00:00 15.39
# trending up
# 7 days, 0:00:00 17.98
# trending up
# 7 days, 0:00:00 17.18
# trending up
# 7 days, 0:00:00 17.41
# trending up
# 8 days, 0:00:00 18.08

# %%
from sql import *

# %%
from pandas import *

# %%
atvi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1043 entries, 2010-01-04 00:00:00 to 2014-02-25 00:00:00
# Data columns (total 6 columns):
# Open         1043  non-null values
# High         1043  non-null values
# Low          1043  non-null values
# Close        1043  non-null values
# Volume       1043  non-null values
# Adj Close    1043  non-null values
# dtypes: float64(5), int64(1)

# %%
ea
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1043 entries, 2010-01-04 00:00:00 to 2014-02-25 00:00:00
# Data columns (total 6 columns):
# Open         1043  non-null values
# High         1043  non-null values
# Low          1043  non-null values
# Close        1043  non-null values
# Volume       1043  non-null values
# Adj Close    1043  non-null values
# dtypes: float64(5), int64(1)

# %% [markdown]
# This merges the two tables keeping the common index

# %%
merged = concat([atvi, ea], axis=1)

# %%
merged.tail()
# Out:
#              Open   High    Low  Close   Volume  Adj Close   Open   High  \
# Date
# 2014-02-19  19.90  20.00  19.57  19.68  7840400      19.68  28.18  28.44
# 2014-02-20  19.66  19.84  19.59  19.63  5095200      19.63  28.00  28.14
# 2014-02-21  19.75  19.92  19.70  19.72  7827500      19.72  27.80  28.21
# 2014-02-24  19.70  19.87  19.63  19.69  6421700      19.69  28.03  28.33
# 2014-02-25  19.78  19.79  19.37  19.46  5294900      19.46  28.04  28.16
#
#               Low  Close   Volume  Adj Close
# Date
# 2014-02-19  27.89  27.91  3398400      27.91
# 2014-02-20  27.67  27.79  4224800      27.79
# 2014-02-21  27.80  28.00  3743800      28.00
# 2014-02-24  27.95  27.96  2294100      27.96
# 2014-02-25  27.67  28.10  3410200      28.10

# %% [markdown]
# Multiple columns have the same name. Rename the columns.

# %%
merged.columns = ["atvi_Open", "atvi_High", "atvi_Low", "atvi_Close", "atvi_Volume", "atvi_Adj Close",
                  "ea_Open", "ea_High", "ea_Low", "ea_Close", "ea_Volume", "ea_Adj Close"]
merged.tail()
# Out:
#             atvi_Open  atvi_High  atvi_Low  atvi_Close  atvi_Volume  \
# Date
# 2014-02-19      19.90      20.00     19.57       19.68      7840400
# 2014-02-20      19.66      19.84     19.59       19.63      5095200
# 2014-02-21      19.75      19.92     19.70       19.72      7827500
# 2014-02-24      19.70      19.87     19.63       19.69      6421700
# 2014-02-25      19.78      19.79     19.37       19.46      5294900
#
#             atvi_Adj Close  ea_Open  ea_High  ea_Low  ea_Close  ea_Volume  \
# Date
# 2014-02-19           19.68    28.18    28.44   27.89     27.91    3398400
# 2014-02-20           19.63    28.00    28.14   27.67     27.79    4224800
# 2014-02-21           19.72    27.80    28.21   27.80     28.00    3743800
# 2014-02-24           19.69    28.03    28.33   27.95     27.96    2294100
# 2014-02-25           19.46    28.04    28.16   27.67     28.10    3410200
#
#             ea_Adj Close
# Date
# 2014-02-19         27.91
# 2014-02-20         27.79
# 2014-02-21         28.00
# 2014-02-24         27.96
# 2014-02-25         28.10

# %%
plt.figure()
merged["atvi_Adj Close"].plot("atvi")
merged["ea_Adj Close"].plot("ea")
plt.legend()

# %%
moments.rolling_mean(atvi["Adj Close"], 60).plot(style='k')

# %%
atvi["Adj Close"].std()
# Out:
# 2.3468198058564478

# %%
moments.rolling_std(atvi["Adj Close"], 60).plot(style='k')
