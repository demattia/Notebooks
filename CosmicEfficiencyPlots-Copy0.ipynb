# %%
import ROOT
from ROOT import TCanvas
import rootprint
import rootnotes

# %%
ROOT.gStyle.SetOptStat(0000000)

# %%
inputFileData = ROOT.TFile("/home/demattia/cmslpc/uscms_data/d3/demattia/DisplacedLeptons/RefittedStandAloneMuons/Analysis/CMSSW_5_3_7/src/Analysis/TrackingEfficiencyFromCosmics/test/Macros/TreeAnalyzers/eff_data_dz10.root")
inputFileMC = ROOT.TFile("/home/demattia/cmslpc/uscms_data/d3/demattia/DisplacedLeptons/RefittedStandAloneMuons/Analysis/CMSSW_5_3_7/src/Analysis/TrackingEfficiencyFromCosmics/test/Macros/TreeAnalyzers/eff_MC_dz10.root")

# %%
def draw(name, normalize=False):

    hData = inputFileData.Get(name)
    hMC = inputFileMC.Get(name)
    hMC.SetLineColor(2)

    if normalize:
        hData.Scale(1./hData.Integral())
        hMC.Scale(1./hMC.Integral())

    maxPlusErrorData = hData.GetBinContent(hData.GetMaximumBin())
    maxPlusErrorMC = hMC.GetBinContent(hMC.GetMaximumBin())
    # Because SetRangeUser and SetLimits do not work
    if maxPlusErrorData > maxPlusErrorMC:
        hData.Draw()
        hMC.Draw("same")
    else:
        hMC.Draw()
        hData.Draw("same")
    # hData.GetYaxis().SetLimits(0, max(maxPlusErrorMC, maxPlusErrorData))
    
    leg = ROOT.TLegend(0.15,0.7,0.4,0.85);
    leg.AddEntry(hData,"Data");
    leg.AddEntry(hMC,"MC");
    leg.SetBorderSize(0)
    leg.Draw();

    return leg

# %%
# %%rootprint
# inputFileData.ls()
# Out:
# TFile**		/home/demattia/cmslpc/uscms_data/d3/demattia/DisplacedLeptons/RefittedStandAloneMuons/Analysis/CMSSW_5_3_7/src/Analysis/TrackingEfficiencyFromCosmics/test/Macros/TreeAnalyzers/eff_data_dz10.root
#  TFile*		/home/demattia/cmslpc/uscms_data/d3/demattia/DisplacedLeptons/RefittedStandAloneMuons/Analysis/CMSSW_5_3_7/src/Analysis/TrackingEfficiencyFromCosmics/test/Macros/TreeAnalyzers/eff_data_dz10.root
#   KEY: TH1F	passingVsD0;1	tracks found vs |d_{0}|
#   KEY: TH1F	totalVsD0;1	cosmics found vs |d_{0}| (filled twice)
#   KEY: TH1F	effVsD0;1	tracks found vs |d_{0}|
#   KEY: TH1F	PhiAll;1	muon #phi
#   KEY: TH1F	PhiAfterSel;1	muon #phi
#   KEY: TH1F	TotalPhi;1	muon 1 #phi
#   KEY: TH1F	PassingPhi;1	muon 2 #phi
#   KEY: TH1F	TotalEta;1	muon 1 #eta
#   KEY: TH1F	PassingEta;1	muon 2 #eta
#   KEY: TH1F	TotalPt;1	muon 1 pt
#   KEY: TH1F	PassingPt;1	muon 2 pt
#   KEY: TH1F	passingVsPhi;1	tracks found vs #phi
#   KEY: TH1F	totalVsPhi;1	cosmics found vs #phi (filled twice)
#   KEY: TH1F	effVsPhi;1	tracks found vs #phi
#   KEY: TH1F	passingVsEta;1	tracks found vs #eta
#   KEY: TH1F	totalVsEta;1	cosmics found vs #eta (filled twice)
#   KEY: TH1F	effVsEta;1	tracks found vs #eta
#   KEY: TH1F	passingVsPt;1	tracks found vs p_{T}
#   KEY: TH1F	totalVsPt;1	cosmics found vs p_{T} (filled twice)
#   KEY: TH1F	effVsPt;1	tracks found vs p_{T}
#   KEY: TH1F	passingVsValidHits;1	tracks found vs valid hits
#   KEY: TH1F	totalVsValidHits;1	cosmics found vs valid hits (filled twice)
#   KEY: TH1F	passingVsDz;1	tracks found vs |d_{z}|
#   KEY: TH1F	totalVsDz;1	cosmics found vs |d_{z}| (filled twice)
#   KEY: TH1F	effVsDz;1	tracks found vs |d_{z}|
#   KEY: TH1F	passingVsChi2;1	tracks found vs #chi^{2}/ndof
#   KEY: TH1F	totalVsChi2;1	cosmics found vs #chi^{2}/ndof (filled twice)
#   KEY: TH2F	validHitsVsEtaAll;1	validHitsVsEtaAll
#   KEY: TH2F	validHitsVsEtaAfterSel;1	validHitsVsEtaAfterSel
#   KEY: TH2F	totalD0errVsPt;1	totalD0errVsPt
#   KEY: TH2F	totalDzerrVsPt;1	totalDzerrVsPt
#   KEY: TH2F	totalD0VsDz;1	totalD0VsDz
#   KEY: TH1F	etaRelError;1	relative error on #eta
#   KEY: TH1F	dxyRelError;1	relative error on d_{0}
#   KEY: TH1F	dzRelError;1	relative error on z_{0}

# %%
c1 = TCanvas("c1", "c1", 800, 2000)
c1.Divide(2,5)
c1.cd(1)
a = draw("TotalEta", True)
c1.cd(2)
b = draw("PassingEta", True)
c1.cd(3)
draw("TotalPhi", True)
c1.cd(4)
draw("PassingPhi", True)
c1.cd(5)
draw("TotalPt", True)
c1.cd(6)
draw("PassingPt", True)
c1.cd(7)
draw("totalVsChi2", True)
c1.cd(8)
draw("passingVsChi2", True)
c1.cd(9)
draw("totalVsValidHits", True)
c1.cd(10)
draw("passingVsValidHits", True)
c1
# Out:
# <ROOT.TCanvas object ("c1") at 0x39baf20>

# %%
c1 = TCanvas("c1", "c1", 800, 400)
c1.Divide(2,1)
c1.cd(1)
a = draw("PhiAll", True)
c1.cd(2)
b = draw("PhiAfterSel", True)
c1
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: c1
# <ROOT.TCanvas object ("c1") at 0x39c20a0>

# %%
c4 = TCanvas("c4", "c4", 800, 2800)
c4.Divide(2,7)
c4.cd(1)
draw("totalVsEta", True)
c4.cd(2)
draw("passingVsEta", True)
c4.cd(3)
draw("totalVsPhi", True)
c4.cd(4)
draw("passingVsPhi", True)
c4.cd(5)
draw("totalVsPt", True)
c4.cd(6)
draw("passingVsPt", True)
c4.cd(7)
draw("totalVsD0", True)
c4.cd(8)
draw("passingVsD0", True)
c4.cd(9)
draw("totalVsDz", True)
c4.cd(10)
draw("passingVsDz", True)
c4.cd(11)
draw("totalVsValidHits", True)
c4.cd(12)
draw("passingVsValidHits", True)
c4.cd(13)
draw("totalVsChi2", True)
c4.cd(14)
draw("passingVsChi2", True)
c4
# Out:
# <ROOT.TCanvas object ("c4") at 0x3c8d7f0>

# %%
c3 = TCanvas("c3", "c3", 800, 400)
c3.Divide(2,1)
c3.cd(1)
l = draw("effVsD0")
c3.cd(2)
draw("effVsDz")
c3
# Out:
# <ROOT.TCanvas object ("c3") at 0x3cae9d0>
