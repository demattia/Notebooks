# %%
import sys
sys.path.append('/Users/demattia/Desktop/Notebooks')
import rootprint
import rootnotes
from array import array
# import LinearFitterHistograms

import ROOT
from ROOT import TFile, TH1F, TCanvas, TLegend, TGraphErrors
import math
from itertools import chain
import numpy as np
import matplotlib.pyplot as plt
import pylab
# %matplotlib inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
ROOT.gStyle.SetOptStat(0)

# %%
# base_dir = "/Users/demattia/RemoteProjects/Test/NewConstants/Combinations_Longitudinal/"
base_dir = "/Users/demattia/RemoteProjects/LinearizedTrackFit/LinearizedTrackFit/python/ConstantsProduction/Combinations_Longitudinal_Rz_SecondOrder/"

def get_histos(type_name):
    files = []
    files.append(TFile(base_dir+"Region_1_All/matrixBuilderHistograms.root", "READ"))
    files.append(TFile(base_dir+"Region_2_All/matrixBuilderHistograms.root", "READ"))
    files.append(TFile(base_dir+"Region_3_All/matrixBuilderHistograms.root", "READ"))
    files.append(TFile(base_dir+"Region_4_All/matrixBuilderHistograms.root", "READ"))
    files.append(TFile(base_dir+"Region_5_All/matrixBuilderHistograms.root", "READ"))
    files.append(TFile(base_dir+"Region_6_All/matrixBuilderHistograms.root", "READ"))
    files.append(TFile(base_dir+"Region_7_All/matrixBuilderHistograms.root", "READ"))
    files.append(TFile(base_dir+"Region_8_All/matrixBuilderHistograms.root", "READ"))
    files.append(TFile(base_dir+"Region_9_All/matrixBuilderHistograms.root", "READ"))
                
    h = []
    for i in range(len(files)):
        # h.append(files[i].FindObjectAny("RZ_"+str(i+1)+type_name))
        h.append(files[i].FindObjectAny("RZ_0"+type_name))

    c = TCanvas("c", "c", 1200, 480)
    h[0].Draw()
    h[0].RebinX(6)
    h[0].RebinY(6)
    h[0].GetXaxis().SetTitle("z [cm]")
    h[0].GetYaxis().SetTitle("R [cm]")
    h[0].GetYaxis().SetTitleOffset(1.3)
    h[0].SetTitle("")
    for i in range(1, len(h)):
        h[i].RebinX(6)
        h[i].RebinY(6)
        h[i].Draw("same")
        h[i].SetMarkerColor(i+1)

    return c, h, files

# %%
c, h, files = get_histos("")
c
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: c
# <ROOT.TCanvas object ("c") at 0x7fb6cd45cc30>

# %%
c, h, files = get_histos("Corr")
c
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: c
# <ROOT.TCanvas object ("c") at 0x7fb6cd50cd10>
