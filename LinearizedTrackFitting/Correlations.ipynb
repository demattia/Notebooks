# %% [markdown]
# # Correlations

# %% [markdown]
# We study the correlations between track parameters and stub coordinates.

# %%
import sys
sys.path.append('/Users/demattia/Desktop/Notebooks')
import rootprint
import rootnotes
from array import array

from ROOT import TFile, TH1F, TCanvas, TLegend, TGraphErrors
import math

# %%
input_file = TFile("/Users/demattia/RemoteProjects/Test/correlationHistograms.root")

# %%
def draw_in_canvas(input_file, c, name, i):
    c.cd(i)
    h = input_file.Get(name)
    # h.GetYaxis().SetRangeUser(0.1, 0.6)
    # print name
    h.Draw("COLZ")
    return h

# %%
c_pos = TCanvas("c", "c", 800, 1200)
c_pos.Divide(2, 3)
h = []
i = 0
for j in range(1, 7):
    h.append(draw_in_canvas(input_file, c_pos, "DeltaS_"+str(i)+"_vs_chargeOverPt_positive", j))
    i+=4
c_pos
# Out:
# <ROOT.TCanvas object ("c") at 0x7f8260876780>

# %%
c_neg = TCanvas("c", "c", 800, 1200)
c_neg.Divide(2, 3)
h = []
i = 0
for j in range(1, 7):
    h.append(draw_in_canvas(input_file, c_neg, "DeltaS_"+str(i)+"_vs_chargeOverPt_negative", j))
    i+=4
c_neg
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: c
# <ROOT.TCanvas object ("c") at 0x7f8261850b10>

# %%
c_pos = TCanvas("c", "c", 800, 1200)
c_pos.Divide(2, 3)
h = []
i = 2
for j in range(1, 7):
    h.append(draw_in_canvas(input_file, c_pos, "z_"+str(i)+"_vs_cotTheta_positive", j))
    i+=4
c_pos
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: c
# <ROOT.TCanvas object ("c") at 0x7f8261855320>

# %%
c_pos = TCanvas("c", "c", 800, 1200)
c_pos.Divide(2, 3)
h = []
i = 3
for j in range(1, 7):
    h.append(draw_in_canvas(input_file, c_pos, "z_"+str(i)+"_vs_z0_positive", j))
    i+=4
c_pos
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: c
# <ROOT.TCanvas object ("c") at 0x7f8261856400>
